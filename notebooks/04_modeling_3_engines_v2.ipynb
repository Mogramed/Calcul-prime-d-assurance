# %% [markdown]
# # 04 - Modeling 3 Engines V2
#
# Benchmark principal V2.
# - Phase B: coarse configs (6/moteur en mode full),
# - Phase C: robustesse multi-seeds sur top configs.

# %%
import sys
from pathlib import Path
import pandas as pd

ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.v2_pipeline import (
    DEFAULT_V2_DIR,
    ensure_dir,
    load_train_test,
    prepare_feature_sets,
    build_split_registry,
    run_benchmark,
    V2_COARSE_CONFIGS,
)

DATA_DIR = ROOT / "data"
ARTIFACT_V2 = ensure_dir(ROOT / DEFAULT_V2_DIR)

RUN_FULL = False      # True pour overnight 8-12h
QUICK_CFG_PER_ENGINE = 1
QUICK_TOP2_PER_ENGINE = 1

# %%
train_raw, test_raw = load_train_test(DATA_DIR)
feature_sets = prepare_feature_sets(train_raw, test_raw, rare_min_count=30, drop_identifiers=True)
bundle = feature_sets["base_v2"]
splits = build_split_registry(train_raw, n_blocks_time=5, n_splits_group=5, group_col="id_client")

if RUN_FULL:
    families = ["two_part_classic", "two_part_tweedie", "direct_tweedie"]
    sev_modes = ["classic", "weighted_tail", "winsorized"]
    tweedie_powers = [1.3, 1.5, 1.7]
    seeds = [42, 2026]
    calibs = ["none", "isotonic"]
    cfg_per_engine = 6
else:
    families = ["two_part_classic", "two_part_tweedie", "direct_tweedie"]
    sev_modes = ["classic", "weighted_tail"]
    tweedie_powers = [1.5]
    seeds = [42]
    calibs = ["none", "isotonic"]
    cfg_per_engine = QUICK_CFG_PER_ENGINE

# %%
all_f = []
all_r = []
all_p = []

for engine in ["catboost", "lightgbm", "xgboost"]:
    cfgs = V2_COARSE_CONFIGS[engine][:cfg_per_engine]
    for cfg in cfgs:
        for fam in families:
            for sev_mode in sev_modes:
                if fam == "direct_tweedie" and sev_mode != "classic":
                    continue
                for tw_power in (tweedie_powers if fam == "two_part_tweedie" else [1.5]):
                    for seed in seeds:
                        spec = {
                            "feature_set": "base_v2",
                            "engine": engine,
                            "family": fam,
                            "severity_mode": sev_mode,
                            "tweedie_power": tw_power,
                            "config_id": cfg["config_id"],
                            "calibration_methods": calibs,
                            "use_tail_mapper": fam != "direct_tweedie",
                            "use_target_encoding": True,
                            "target_encode_cols": ["code_postal", "cp3", "modele_vehicule", "marque_modele"],
                            "target_encoding_smoothing": 20.0,
                            "freq_params": cfg["freq_params"],
                            "sev_params": cfg["sev_params"],
                            "direct_params": cfg["direct_params"],
                        }
                        print("[run]", engine, cfg["config_id"], fam, sev_mode, tw_power, "seed", seed)
                        f, r, p = run_benchmark(spec, bundle=bundle, splits=splits, seed=seed)
                        all_f.append(f)
                        all_r.append(r)
                        all_p.append(p)

fold_df = pd.concat(all_f, ignore_index=True)
run_df = pd.concat(all_r, ignore_index=True)
pred_df = pd.concat(all_p, ignore_index=True)

run_df.to_csv(ARTIFACT_V2 / "run_registry_v2.csv", index=False)
pred_df.to_parquet(ARTIFACT_V2 / "oof_predictions_v2.parquet", index=False)
print("saved:", ARTIFACT_V2 / "run_registry_v2.csv")
print("saved:", ARTIFACT_V2 / "oof_predictions_v2.parquet")
run_df.sort_values(["split", "rmse_prime"]).head(50)
# Out:
# [run] catboost cb_v2_c1 two_part_classic classic 1.5 seed 42
# [run] catboost cb_v2_c1 two_part_classic weighted_tail 1.5 seed 42
# [run] catboost cb_v2_c1 two_part_tweedie classic 1.5 seed 42
# [run] catboost cb_v2_c1 two_part_tweedie weighted_tail 1.5 seed 42
# [run] catboost cb_v2_c1 direct_tweedie classic 1.5 seed 42
# [run] lightgbm lgb_v2_c1 two_part_classic classic 1.5 seed 42
# [run] lightgbm lgb_v2_c1 two_part_classic weighted_tail 1.5 seed 42
# [run] lightgbm lgb_v2_c1 two_part_tweedie classic 1.5 seed 42
# [run] lightgbm lgb_v2_c1 two_part_tweedie weighted_tail 1.5 seed 42
# [run] lightgbm lgb_v2_c1 direct_tweedie classic 1.5 seed 42
# [run] xgboost xgb_v2_c1 two_part_classic classic 1.5 seed 42
# [run] xgboost xgb_v2_c1 two_part_classic weighted_tail 1.5 seed 42
# [run] xgboost xgb_v2_c1 two_part_tweedie classic 1.5 seed 42
# [run] xgboost xgb_v2_c1 two_part_tweedie weighted_tail 1.5 seed 42
# [run] xgboost xgb_v2_c1 direct_tweedie classic 1.5 seed 42
# saved: c:\Users\icemo\Downloads\Calcul-prime-d-assurance\artifacts\v2\run_registry_v2.csv
# saved: c:\Users\icemo\Downloads\Calcul-prime-d-assurance\artifacts\v2\oof_predictions_v2.parquet
#    level         split feature_set    engine            family  config_id  \
# 17   run  aux_blocked5     base_v2  catboost  two_part_tweedie   cb_v2_c1
# 16   run  aux_blocked5     base_v2  catboost  two_part_tweedie   cb_v2_c1
# 11   run  aux_blocked5     base_v2  catboost  two_part_classic   cb_v2_c1
# 10   run  aux_blocked5     base_v2  catboost  two_part_classic   cb_v2_c1
# 23   run  aux_blocked5     base_v2  catboost  two_part_tweedie   cb_v2_c1
# 22   run  aux_blocked5     base_v2  catboost  two_part_tweedie   cb_v2_c1
# 5    run  aux_blocked5     base_v2  catboost  two_part_classic   cb_v2_c1
# 4    run  aux_blocked5     base_v2  catboost  two_part_classic   cb_v2_c1
# 77   run  aux_blocked5     base_v2   xgboost  two_part_tweedie  xgb_v2_c1
# 65   run  aux_blocked5     base_v2   xgboost  two_part_classic  xgb_v2_c1
# 76   run  aux_blocked5     base_v2   xgboost  two_part_tweedie  xgb_v2_c1
# 64   run  aux_blocked5     base_v2   xgboost  two_part_classic  xgb_v2_c1
# 59   run  aux_blocked5     base_v2   xgboost  two_part_classic  xgb_v2_c1
# 71   run  aux_blocked5     base_v2   xgboost  two_part_tweedie  xgb_v2_c1
# 58   run  aux_blocked5     base_v2   xgboost  two_part_classic  xgb_v2_c1
# 70   run  aux_blocked5     base_v2   xgboost  two_part_tweedie  xgb_v2_c1
# 26   run  aux_blocked5     base_v2  catboost    direct_tweedie   cb_v2_c1
# 38   run  aux_blocked5     base_v2  lightgbm  two_part_classic  lgb_v2_c1
# 50   run  aux_blocked5     base_v2  lightgbm  two_part_tweedie  lgb_v2_c1
# 44   run  aux_blocked5     base_v2  lightgbm  two_part_tweedie  lgb_v2_c1
# 32   run  aux_blocked5     base_v2  lightgbm  two_part_classic  lgb_v2_c1
# 37   run  aux_blocked5     base_v2  lightgbm  two_part_classic  lgb_v2_c1
# 49   run  aux_blocked5     base_v2  lightgbm  two_part_tweedie  lgb_v2_c1
# 43   run  aux_blocked5     base_v2  lightgbm  two_part_tweedie  lgb_v2_c1
# 31   run  aux_blocked5     base_v2  lightgbm  two_part_classic  lgb_v2_c1
# 80   run  aux_blocked5     base_v2   xgboost    direct_tweedie  xgb_v2_c1
# 53   run  aux_blocked5     base_v2  lightgbm    direct_tweedie  lgb_v2_c1
# 19   run  primary_time     base_v2  catboost  two_part_tweedie   cb_v2_c1
# 7    run  primary_time     base_v2  catboost  two_part_classic   cb_v2_c1
# 13   run  primary_time     base_v2  catboost  two_part_tweedie   cb_v2_c1
# 1    run  primary_time     base_v2  catboost  two_part_classic   cb_v2_c1
# 60   run  primary_time     base_v2   xgboost  two_part_classic  xgb_v2_c1
# 61   run  primary_time     base_v2   xgboost  two_part_classic  xgb_v2_c1
# 55   run  primary_time     base_v2   xgboost  two_part_classic  xgb_v2_c1
# 66   run  primary_time     base_v2   xgboost  two_part_tweedie  xgb_v2_c1
# 54   run  primary_time     base_v2   xgboost  two_part_classic  xgb_v2_c1
# 67   run  primary_time     base_v2   xgboost  two_part_tweedie  xgb_v2_c1
# 72   run  primary_time     base_v2   xgboost  two_part_tweedie  xgb_v2_c1
# 28   run  primary_time     base_v2  lightgbm  two_part_classic  lgb_v2_c1
# 73   run  primary_time     base_v2   xgboost  two_part_tweedie  xgb_v2_c1
# 34   run  primary_time     base_v2  lightgbm  two_part_classic  lgb_v2_c1
# 40   run  primary_time     base_v2  lightgbm  two_part_tweedie  lgb_v2_c1
# 46   run  primary_time     base_v2  lightgbm  two_part_tweedie  lgb_v2_c1
# 18   run  primary_time     base_v2  catboost  two_part_tweedie   cb_v2_c1
# 27   run  primary_time     base_v2  lightgbm  two_part_classic  lgb_v2_c1
# 39   run  primary_time     base_v2  lightgbm  two_part_tweedie  lgb_v2_c1
# 33   run  primary_time     base_v2  lightgbm  two_part_classic  lgb_v2_c1
# 45   run  primary_time     base_v2  lightgbm  two_part_tweedie  lgb_v2_c1
# 6    run  primary_time     base_v2  catboost  two_part_classic   cb_v2_c1
# 12   run  primary_time     base_v2  catboost  two_part_tweedie   cb_v2_c1
#
#     seed  severity_mode calibration tail_mapper  fold_id  n_valid  rmse_prime  \
# 17    42        classic    isotonic    isotonic       -1    50000  542.571435
# 16    42        classic        none    isotonic       -1    50000  542.575544
# 11    42  weighted_tail    isotonic    isotonic       -1    50000  542.577648
# 10    42  weighted_tail        none    isotonic       -1    50000  542.578502
# 23    42  weighted_tail    isotonic    isotonic       -1    50000  542.595859
# 22    42  weighted_tail        none    isotonic       -1    50000  542.611299
# 5     42        classic    isotonic    isotonic       -1    50000  542.670668
# 4     42        classic        none    isotonic       -1    50000  542.681086
# 77    42  weighted_tail    isotonic    isotonic       -1    50000  542.841891
# 65    42  weighted_tail    isotonic    isotonic       -1    50000  542.842109
# 76    42  weighted_tail        none    isotonic       -1    50000  542.842493
# 64    42  weighted_tail        none    isotonic       -1    50000  542.854402
# 59    42        classic    isotonic    isotonic       -1    50000  542.877905
# 71    42        classic    isotonic    isotonic       -1    50000  542.883211
# 58    42        classic        none    isotonic       -1    50000  542.886507
# 70    42        classic        none    isotonic       -1    50000  542.888025
# 26    42        classic        none        none       -1    50000  542.958342
# 38    42  weighted_tail    isotonic    isotonic       -1    50000  542.997505
# 50    42  weighted_tail    isotonic    isotonic       -1    50000  543.057173
# 44    42        classic    isotonic    isotonic       -1    50000  543.068630
# 32    42        classic    isotonic    isotonic       -1    50000  543.121771
# 37    42  weighted_tail        none    isotonic       -1    50000  543.151227
# 49    42  weighted_tail        none    isotonic       -1    50000  543.217698
# 43    42        classic        none    isotonic       -1    50000  543.238704
# 31    42        classic        none    isotonic       -1    50000  543.302374
# 80    42        classic        none        none       -1    50000  543.417720
# 53    42        classic        none        none       -1    50000  543.817164
# 19    42  weighted_tail    isotonic    isotonic       -1    40000  543.897946
# 7     42  weighted_tail    isotonic    isotonic       -1    40000  544.010358
# 13    42        classic    isotonic    isotonic       -1    40000  544.026383
# 1     42        classic    isotonic    isotonic       -1    40000  544.092828
# 60    42  weighted_tail        none    isotonic       -1    40000  544.311147
# 61    42  weighted_tail    isotonic    isotonic       -1    40000  544.315178
# 55    42        classic    isotonic    isotonic       -1    40000  544.318236
# 66    42        classic        none    isotonic       -1    40000  544.322745
# 54    42        classic        none    isotonic       -1    40000  544.330795
# 67    42        classic    isotonic    isotonic       -1    40000  544.336071
# 72    42  weighted_tail        none    isotonic       -1    40000  544.338690
# 28    42        classic    isotonic    isotonic       -1    40000  544.351093
# 73    42  weighted_tail    isotonic    isotonic       -1    40000  544.357441
# 34    42  weighted_tail    isotonic    isotonic       -1    40000  544.363780
# 40    42        classic    isotonic    isotonic       -1    40000  544.375058
# 46    42  weighted_tail    isotonic    isotonic       -1    40000  544.393471
# 18    42  weighted_tail        none    isotonic       -1    40000  544.455021
# 27    42        classic        none    isotonic       -1    40000  544.456448
# 39    42        classic        none    isotonic       -1    40000  544.471989
# 33    42  weighted_tail        none    isotonic       -1    40000  544.474306
# 45    42  weighted_tail        none    isotonic       -1    40000  544.501345
# 6     42  weighted_tail        none    isotonic       -1    40000  544.507423
# 12    42        classic        none    isotonic       -1    40000  544.600449
#
#     auc_freq  brier_freq  rmse_sev_pos  q99_ratio_pos  \
# 17  0.635468    0.054255   1461.456772       0.283293
# 16  0.638932    0.054260   1461.456772       0.283293
# 11  0.635468    0.054255   1462.643524       0.297873
# 10  0.638932    0.054260   1462.643524       0.297873
# 23  0.635468    0.054255   1461.475757       0.298799
# 22  0.638932    0.054260   1461.475757       0.298799
# 5   0.635468    0.054255   1464.672223       0.294504
# 4   0.638932    0.054260   1464.672223       0.294504
# 77  0.630252    0.054308   1461.418314       0.303062
# 65  0.630252    0.054308   1462.489815       0.283711
# 76  0.633913    0.054322   1461.418314       0.303062
# 64  0.633913    0.054322   1462.489815       0.283711
# 59  0.630252    0.054308   1463.455944       0.302342
# 71  0.630252    0.054308   1462.427797       0.288082
# 58  0.633913    0.054322   1463.455944       0.302342
# 70  0.633913    0.054322   1462.427797       0.288082
# 26  0.638932    0.054260   1498.943882       0.333277
# 38  0.624501    0.054391   1461.028507       0.290501
# 50  0.624501    0.054391   1464.470975       0.283921
# 44  0.624501    0.054391   1462.923627       0.290083
# 32  0.624501    0.054391   1463.398436       0.285694
# 37  0.628197    0.054451   1461.028507       0.290501
# 49  0.628197    0.054451   1464.470975       0.283921
# 43  0.628197    0.054451   1462.923627       0.290083
# 31  0.628197    0.054451   1463.398436       0.285694
# 80  0.633913    0.054322   1517.823736       0.314290
# 53  0.628197    0.054451   1534.627182       0.326298
# 19  0.608750    0.054531   1462.342755       0.328733
# 7   0.608750    0.054531   1465.576018       0.294376
# 13  0.608750    0.054531   1464.030305       0.321118
# 1   0.608750    0.054531   1464.368583       0.310240
# 60  0.596404    0.054642   1468.146994       0.314437
# 61  0.592184    0.054663   1468.146994       0.314437
# 55  0.592184    0.054663   1467.514869       0.319171
# 66  0.596404    0.054642   1467.032305       0.330594
# 54  0.596404    0.054642   1467.514869       0.319171
# 67  0.592184    0.054663   1467.032305       0.330594
# 72  0.596404    0.054642   1469.836887       0.299646
# 28  0.585993    0.054680   1466.979389       0.336075
# 73  0.592184    0.054663   1469.836887       0.299646
# 34  0.585993    0.054680   1465.391311       0.297356
# 40  0.585993    0.054680   1464.069142       0.301686
# 46  0.585993    0.054680   1467.564710       0.288591
# 18  0.612200    0.054695   1462.342755       0.328733
# 27  0.591716    0.054714   1466.979389       0.336075
# 39  0.591716    0.054714   1464.069142       0.301686
# 33  0.591716    0.054714   1465.391311       0.297356
# 45  0.591716    0.054714   1467.564710       0.288591
# 6   0.612200    0.054695   1465.576018       0.294376
# 12  0.612200    0.054695   1464.030305       0.321118
#
#                                                run_id
# 17  base_v2|catboost|two_part_tweedie|cb_v2_c1|42|...
# 16  base_v2|catboost|two_part_tweedie|cb_v2_c1|42|...
# 11  base_v2|catboost|two_part_classic|cb_v2_c1|42|...
# 10  base_v2|catboost|two_part_classic|cb_v2_c1|42|...
# 23  base_v2|catboost|two_part_tweedie|cb_v2_c1|42|...
# 22  base_v2|catboost|two_part_tweedie|cb_v2_c1|42|...
# 5   base_v2|catboost|two_part_classic|cb_v2_c1|42|...
# 4   base_v2|catboost|two_part_classic|cb_v2_c1|42|...
# 77  base_v2|xgboost|two_part_tweedie|xgb_v2_c1|42|...
# 65  base_v2|xgboost|two_part_classic|xgb_v2_c1|42|...
# 76  base_v2|xgboost|two_part_tweedie|xgb_v2_c1|42|...
# 64  base_v2|xgboost|two_part_classic|xgb_v2_c1|42|...
# 59  base_v2|xgboost|two_part_classic|xgb_v2_c1|42|...
# 71  base_v2|xgboost|two_part_tweedie|xgb_v2_c1|42|...
# 58  base_v2|xgboost|two_part_classic|xgb_v2_c1|42|...
# 70  base_v2|xgboost|two_part_tweedie|xgb_v2_c1|42|...
# 26  base_v2|catboost|direct_tweedie|cb_v2_c1|42|cl...
# 38  base_v2|lightgbm|two_part_classic|lgb_v2_c1|42...
# 50  base_v2|lightgbm|two_part_tweedie|lgb_v2_c1|42...
# 44  base_v2|lightgbm|two_part_tweedie|lgb_v2_c1|42...
# 32  base_v2|lightgbm|two_part_classic|lgb_v2_c1|42...
# 37  base_v2|lightgbm|two_part_classic|lgb_v2_c1|42...
# 49  base_v2|lightgbm|two_part_tweedie|lgb_v2_c1|42...
# 43  base_v2|lightgbm|two_part_tweedie|lgb_v2_c1|42...
# 31  base_v2|lightgbm|two_part_classic|lgb_v2_c1|42...
# 80  base_v2|xgboost|direct_tweedie|xgb_v2_c1|42|cl...
# 53  base_v2|lightgbm|direct_tweedie|lgb_v2_c1|42|c...
# 19  base_v2|catboost|two_part_tweedie|cb_v2_c1|42|...
# 7   base_v2|catboost|two_part_classic|cb_v2_c1|42|...
# 13  base_v2|catboost|two_part_tweedie|cb_v2_c1|42|...
# 1   base_v2|catboost|two_part_classic|cb_v2_c1|42|...
# 60  base_v2|xgboost|two_part_classic|xgb_v2_c1|42|...
# 61  base_v2|xgboost|two_part_classic|xgb_v2_c1|42|...
# 55  base_v2|xgboost|two_part_classic|xgb_v2_c1|42|...
# 66  base_v2|xgboost|two_part_tweedie|xgb_v2_c1|42|...
# 54  base_v2|xgboost|two_part_classic|xgb_v2_c1|42|...
# 67  base_v2|xgboost|two_part_tweedie|xgb_v2_c1|42|...
# 72  base_v2|xgboost|two_part_tweedie|xgb_v2_c1|42|...
# 28  base_v2|lightgbm|two_part_classic|lgb_v2_c1|42...
# 73  base_v2|xgboost|two_part_tweedie|xgb_v2_c1|42|...
# 34  base_v2|lightgbm|two_part_classic|lgb_v2_c1|42...
# 40  base_v2|lightgbm|two_part_tweedie|lgb_v2_c1|42...
# 46  base_v2|lightgbm|two_part_tweedie|lgb_v2_c1|42...
# 18  base_v2|catboost|two_part_tweedie|cb_v2_c1|42|...
# 27  base_v2|lightgbm|two_part_classic|lgb_v2_c1|42...
# 39  base_v2|lightgbm|two_part_tweedie|lgb_v2_c1|42...
# 33  base_v2|lightgbm|two_part_classic|lgb_v2_c1|42...
# 45  base_v2|lightgbm|two_part_tweedie|lgb_v2_c1|42...
# 6   base_v2|catboost|two_part_classic|cb_v2_c1|42|...
# 12  base_v2|catboost|two_part_tweedie|cb_v2_c1|42|...
